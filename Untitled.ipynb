# %%
from pyimagesearch.transform import four_point_transform
from skimage.filters import threshold_local

import numpy as np
import argparse
import cv2
import imutils
import matplotlib.pyplot as plt

# %%
image = cv2.imread('./out/fd2eafb3-e7b8-4793-a15b-5ae15bdab7f9-1.jpg')
ratio = image.shape[0] / 500.0
orig = image.copy()
image = imutils.resize(image, height = 500)

# %%
plt.imshow(image)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray = cv2.GaussianBlur(gray, (5, 5), 0)
edged = cv2.Canny(gray, 10, 50)

# %%
fig, ax = plt.subplots(figsize=(16,8))
plt.imshow(edged)

# %%
cnts = cv2.findContours(edged.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)
cnts = sorted(cnts, key = cv2.contourArea, reverse = True)[0:5]

# %%
for c in cnts:
    # approximate the contour
    peri = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.02 * peri, True)

    # if our approximated contour has four points, then we
    # can assume that we have found our screen
    if len(approx) == 4:
        screenCnt = approx
        break

# %%
screenCnt
# Out:
# array([[[301,  43]],
#
#        [[ 49,  44]],
#
#        [[ 50, 460]],
#
#        [[300, 460]]], dtype=int32)

# %%
pt1 = screenCnt[1][0]
pt2 = screenCnt[3][0]

# %%
cropped_image = image[pt1[1]:pt2[1], pt1[0]:pt2[0]]

# %%
plt.imshow(cropped_image)

# %%
fig, ax = plt.subplots(figsize=(16,8))
cv2.drawContours(image, [screenCnt], -1, (0, 255, 0), 2)
plt.imshow( image)

# %%
warped = four_point_transform(orig, screenCnt.reshape(4, 2) * ratio)

# %%
warped = cv2.cvtColor(warped, cv2.COLOR_BGR2GRAY)
T = threshold_local(warped, 11, offset = 10, method = "gaussian")
warped = (warped > T).astype("uint8") * 255

# %%
fig, ax = plt.subplots(figsize=(16,8))
plt.imshow(warped, cmap='gray')
plt.imsave('test_orig_1.jpg', warped)

# %%
cropped_image.shape
# Out:
# (416, 251, 3)

# %%
image1 = cv2.imread('./test_orig_1.jpg')
image2 = cv2.resize(cv2.imread('./test_orig_2.jpg') , ( 1178, 1950) ) 
test = cv2.addWeighted(image1, .5 , image2 , .5, 0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-244-f880f8a8236e> in <module>
#       1 image1 = cv2.imread('./test_orig_1.jpg')
#       2 image2 = cv2.resize(cv2.imread('./test_orig_2.jpg') , ( 1178, 1950) )
# ----> 3 test = cv2.addWeighted(cropped_image, .5 , image2 , .5, 0)
#
# error: OpenCV(4.1.0) /io/opencv/modules/core/src/arithm.cpp:663: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'arithm_op'

# %%
image1.shape, image2.shape
# Out:
# ((1950, 1178, 3), (1950, 1178, 3))

# %%
plt.imshow(test)
plt.imsave('./test_orig_3.jpg', test)

# %%
! pip install pdf2image
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/17/66/fa/943596ab784ee79f804b7ecb79dbe97aee8f7665dbbf9f9d94
# Successfully built pdf2image
# ...

# %%
import pdf2image

# %%
images = pdf2image.convert_from_path('./embeddings/oleObject6.pdf',first_page=1, output_folder='./out', fmt='jpg')

# %%
import cv2
